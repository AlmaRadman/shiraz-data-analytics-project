# %%
import pandas as pd

df = pd.read_csv('داده_کامل_خیابانهای_شیراز.csv')

# %%
print (df)
# Out:
#      نام خیابان    سکانس  جداره و نما  کف سازی پیاده روها  مبلمان شهری  \
# 0    معالی آباد  اول دوم            6                  10          0.5
# 1    معالی آباد      دوم            4                  12          9.5
# 2    معالی آباد      سوم            8                  11          6.0
# 3    معالی آباد    چهارم            8                   9          5.0
# 4    معالی آباد     پنجم           10                   9          6.0
# 5    معالی آباد      ششم            9                   8          5.0
# 6    معالی آباد     هفتم           10                  11          6.0
# 7        ولیعصر  سکانس 1           10                  10          7.4
# 8        ولیعصر  سکانس 2            9                  10          8.9
# 9        ولیعصر  سکانس 3           10                  12          7.8
# 10       ولیعصر  سکانس 4            8                  10          7.1
# 11       ولیعصر  سکانس 5            8                  12          7.3
# ...
