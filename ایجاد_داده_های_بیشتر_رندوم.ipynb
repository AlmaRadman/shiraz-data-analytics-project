# %% [markdown]
#  در این مرحله جهت ارتقای پروژه تعداد داده های ارزیابی کیفیت منظر خیابان های شیراز بصورت رندوم افزایش یافت . داده اولیه مربوط به خیابان معالی آباد بوده است.

# %%
import pandas as pd
import numpy as np

# تنظیم seed برای تکرارپذیری
np.random.seed(42)

# داده‌های معالی‌آباد (داده اولی حاصل تحلیل تصاویر خیابان و ارزیابی و تحلیل در Excel)
moaaliabad_data = [
    {'نام خیابان': 'معالی آباد', 'سکانس': 'اول دوم', 'جداره و نما': 6, 'کف سازی پیاده روها': 10, 'مبلمان شهری': 0.5, 'تبلیغات محیطی': 2, 'عناصر شهری': 0, 'المان های شهری': 0, 'جریان سطحی آب و زه کشی': 4, 'طرح کاشت': 3, 'آسایش محیطی': 2, 'اختلاط کاربری': 4, 'فعالیت در فضاهای عمومی': 0, 'خوانایی فضایی': 6, 'دسترس پذیری': 2, 'ایمنی و امنیت': 2, 'اجتماعی': 2, 'فرهنگی': 0},
    {'نام خیابان': 'معالی آباد', 'سکانس': 'دوم', 'جداره و نما': 4, 'کف سازی پیاده روها': 12, 'مبلمان شهری': 9.5, 'تبلیغات محیطی': 5, 'عناصر شهری': 0, 'المان های شهری': 0, 'جریان سطحی آب و زه کشی': 2, 'طرح کاشت': 6, 'آسایش محیطی': 3, 'اختلاط کاربری': 5, 'فعالیت در فضاهای عمومی': 0, 'خوانایی فضایی': 8, 'دسترس پذیری': 2, 'ایمنی و امنیت': 1, 'اجتماعی': 4, 'فرهنگی': 0},
    {'نام خیابان': 'معالی آباد', 'سکانس': 'سوم', 'جداره و نما': 8, 'کف سازی پیاده روها': 11, 'مبلمان شهری': 6, 'تبلیغات محیطی': 4, 'عناصر شهری': 0, 'المان های شهری': 0, 'جریان سطحی آب و زه کشی': 8, 'طرح کاشت': 5, 'آسایش محیطی': 2, 'اختلاط کاربری': 5, 'فعالیت در فضاهای عمومی': 0, 'خوانایی فضایی': 8, 'دسترس پذیری': 3, 'ایمنی و امنیت': 5, 'اجتماعی': 4, 'فرهنگی': 4},
    {'نام خیابان': 'معالی آباد', 'سکانس': 'چهارم', 'جداره و نما': 8, 'کف سازی پیاده روها': 9, 'مبلمان شهری': 5, 'تبلیغات محیطی': 3, 'عناصر شهری': 0, 'المان های شهری': 0, 'جریان سطحی آب و زه کشی': 4, 'طرح کاشت': 5, 'آسایش محیطی': 0, 'اختلاط کاربری': 5, 'فعالیت در فضاهای عمومی': 0, 'خوانایی فضایی': 10, 'دسترس پذیری': 1, 'ایمنی و امنیت': 1, 'اجتماعی': 4, 'فرهنگی': 4},
    {'نام خیابان': 'معالی آباد', 'سکانس': 'پنجم', 'جداره و نما': 10, 'کف سازی پیاده روها': 9, 'مبلمان شهری': 6, 'تبلیغات محیطی': 5, 'عناصر شهری': 0, 'المان های شهری': 0, 'جریان سطحی آب و زه کشی': 5, 'طرح کاشت': 5, 'آسایش محیطی': 2, 'اختلاط کاربری': 5, 'فعالیت در فضاهای عمومی': 3, 'خوانایی فضایی': 8, 'دسترس پذیری': 2, 'ایمنی و امنیت': 5, 'اجتماعی': 4, 'فرهنگی': 4},
    {'نام خیابان': 'معالی آباد', 'سکانس': 'ششم', 'جداره و نما': 9, 'کف سازی پیاده روها': 8, 'مبلمان شهری': 5, 'تبلیغات محیطی': 3, 'عناصر شهری': 0, 'المان های شهری': 0, 'جریان سطحی آب و زه کشی': 2, 'طرح کاشت': 5, 'آسایش محیطی': 0, 'اختلاط کاربری': 5, 'فعالیت در فضاهای عمومی': 0, 'خوانایی فضایی': 2, 'دسترس پذیری': 2, 'ایمنی و امنیت': 0, 'اجتماعی': 4, 'فرهنگی': 0},
    {'نام خیابان': 'معالی آباد', 'سکانس': 'هفتم', 'جداره و نما': 10, 'کف سازی پیاده روها': 11, 'مبلمان شهری': 6, 'تبلیغات محیطی': 5, 'عناصر شهری': 0, 'المان های شهری': 0, 'جریان سطحی آب و زه کشی': 7.5, 'طرح کاشت': 5, 'آسایش محیطی': 0, 'اختلاط کاربری': 5, 'فعالیت در فضاهای عمومی': 0, 'خوانایی فضایی': 10, 'دسترس پذیری': 2, 'ایمنی و امنیت': 1, 'اجتماعی': 4, 'فرهنگی': 4}
]

# تعریف 17 خیابان جدید با تعداد سکانس بیشتر
streets_config = [
    {'name': 'ولیعصر', 'sequences': 12, 'ranges': {'جداره و نما': (8, 10), 'کف سازی پیاده روها': (10, 12), 'مبلمان شهری': (7, 9), 'تبلیغات محیطی': (4, 5), 'عناصر شهری': (2, 4), 'المان های شهری': (1, 3), 'جریان سطحی آب و زه کشی': (5, 7), 'طرح کاشت': (4, 5), 'آسایش محیطی': (2, 4), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (1, 3), 'خوانایی فضایی': (8, 10), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (4, 5), 'فرهنگی': (1, 3)}},
    {'name': 'زند', 'sequences': 10, 'ranges': {'جداره و نما': (5, 8), 'کف سازی پیاده روها': (7, 10), 'مبلمان شهری': (3, 6), 'تبلیغات محیطی': (2, 4), 'عناصر شهری': (0, 2), 'المان های شهری': (0, 1), 'جریان سطحی آب و زه کشی': (3, 5), 'طرح کاشت': (2, 4), 'آسایش محیطی': (0, 2), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (1, 3), 'خوانایی فضایی': (5, 8), 'دسترس پذیری': (1, 2), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (3, 4), 'فرهنگی': (0, 2)}},
    {'name': 'کریم خان', 'sequences': 10, 'ranges': {'جداره و نما': (6, 9), 'کف سازی پیاده روها': (8, 11), 'مبلمان شهری': (4, 7), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (1, 3), 'المان های شهری': (1, 2), 'جریان سطحی آب و زه کشی': (4, 6), 'طرح کاشت': (3, 5), 'آسایش محیطی': (1, 3), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (1, 2), 'خوانایی فضایی': (7, 9), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (4, 5), 'فرهنگی': (2, 4)}},
    {'name': 'چمران', 'sequences': 11, 'ranges': {'جداره و نما': (9, 11), 'کف سازی پیاده روها': (11, 13), 'مبلمان شهری': (8, 10), 'تبلیغات محیطی': (4, 6), 'عناصر شهری': (3, 4), 'المان های شهری': (2, 4), 'جریان سطحی آب و زه کشی': (6, 8), 'طرح کاشت': (4, 5), 'آسایش محیطی': (3, 5), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (2, 4), 'خوانایی فضایی': (9, 10), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (2, 2), 'اجتماعی': (4, 5), 'فرهنگی': (2, 4)}},
    {'name': 'مطهری', 'sequences': 9, 'ranges': {'جداره و نما': (5, 8), 'کف سازی پیاده روها': (7, 10), 'مبلمان شهری': (3, 6), 'تبلیغات محیطی': (2, 4), 'عناصر شهری': (0, 2), 'المان های شهری': (0, 1), 'جریان سطحی آب و زه کشی': (3, 5), 'طرح کاشت': (3, 4), 'آسایش محیطی': (1, 2), 'اختلاط کاربری': (3, 5), 'فعالیت در فضاهای عمومی': (0, 2), 'خوانایی فضایی': (5, 8), 'دسترس پذیری': (1, 2), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (2, 4), 'فرهنگی': (0, 2)}},
    {'name': 'دکتر شریعتی', 'sequences': 8, 'ranges': {'جداره و نما': (6, 8), 'کف سازی پیاده روها': (8, 10), 'مبلمان شهری': (4, 7), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (1, 3), 'المان های شهری': (0, 2), 'جریان سطحی آب و زه کشی': (4, 6), 'طرح کاشت': (3, 5), 'آسایش محیطی': (1, 3), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (2, 4), 'خوانایی فضایی': (6, 8), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (3, 5), 'فرهنگی': (1, 3)}},
    {'name': 'جمهوری', 'sequences': 9, 'ranges': {'جداره و نما': (4, 7), 'کف سازی پیاده روها': (6, 9), 'مبلمان شهری': (2, 5), 'تبلیغات محیطی': (2, 4), 'عناصر شهری': (0, 2), 'المان های شهری': (0, 1), 'جریان سطحی آب و زه کشی': (2, 4), 'طرح کاشت': (2, 4), 'آسایش محیطی': (0, 2), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (1, 2), 'خوانایی فضایی': (4, 7), 'دسترس پذیری': (1, 2), 'ایمنی و امنیت': (0, 1), 'اجتماعی': (2, 4), 'فرهنگی': (0, 2)}},
    {'name': 'رودکی', 'sequences': 8, 'ranges': {'جداره و نما': (3, 6), 'کف سازی پیاده روها': (5, 8), 'مبلمان شهری': (1, 4), 'تبلیغات محیطی': (1, 3), 'عناصر شهری': (0, 1), 'المان های شهری': (0, 0), 'جریان سطحی آب و زه کشی': (1, 3), 'طرح کاشت': (1, 3), 'آسایش محیطی': (0, 1), 'اختلاط کاربری': (3, 4), 'فعالیت در فضاهای عمومی': (0, 1), 'خوانایی فضایی': (3, 6), 'دسترس پذیری': (1, 2), 'ایمنی و امنیت': (0, 1), 'اجتماعی': (1, 3), 'فرهنگی': (0, 1)}},
    {'name': 'صدرا', 'sequences': 10, 'ranges': {'جداره و نما': (7, 10), 'کف سازی پیاده روها': (9, 12), 'مبلمان شهری': (6, 8), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (2, 3), 'المان های شهری': (1, 2), 'جریان سطحی آب و زه کشی': (5, 7), 'طرح کاشت': (4, 5), 'آسایش محیطی': (2, 3), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (1, 2), 'خوانایی فضایی': (7, 9), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (3, 5), 'فرهنگی': (1, 3)}},
    {'name': 'قصرالدشت', 'sequences': 8, 'ranges': {'جداره و نما': (6, 9), 'کف سازی پیاده روها': (8, 10), 'مبلمان شهری': (4, 7), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (1, 3), 'المان های شهری': (1, 2), 'جریان سطحی آب و زه کشی': (4, 6), 'طرح کاشت': (3, 4), 'آسایش محیطی': (1, 3), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (1, 3), 'خوانایی فضایی': (6, 8), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (3, 4), 'فرهنگی': (1, 2)}},
    {'name': 'افضلی', 'sequences': 7, 'ranges': {'جداره و نما': (5, 7), 'کف سازی پیاده روها': (7, 9), 'مبلمان شهری': (3, 6), 'تبلیغات محیطی': (2, 4), 'عناصر شهری': (0, 2), 'المان های شهری': (0, 1), 'جریان سطحی آب و زه کشی': (3, 5), 'طرح کاشت': (2, 4), 'آسایش محیطی': (1, 2), 'اختلاط کاربری': (3, 5), 'فعالیت در فضاهای عمومی': (1, 2), 'خوانایی فضایی': (5, 7), 'دسترس پذیری': (1, 2), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (2, 4), 'فرهنگی': (0, 2)}},
    {'name': 'معلم', 'sequences': 8, 'ranges': {'جداره و نما': (6, 8), 'کف سازی پیاده روها': (7, 10), 'مبلمان شهری': (4, 6), 'تبلیغات محیطی': (2, 4), 'عناصر شهری': (1, 2), 'المان های شهری': (0, 1), 'جریان سطحی آب و زه کشی': (3, 5), 'طرح کاشت': (3, 4), 'آسایش محیطی': (1, 2), 'اختلاط کاربری': (3, 5), 'فعالیت در فضاهای عمومی': (0, 2), 'خوانایی فضایی': (5, 8), 'دسترس پذیری': (1, 2), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (2, 4), 'فرهنگی': (1, 2)}},
    {'name': 'ستارخان', 'sequences': 7, 'ranges': {'جداره و نما': (5, 7), 'کف سازی پیاده روها': (6, 9), 'مبلمان شهری': (3, 5), 'تبلیغات محیطی': (2, 4), 'عناصر شهری': (0, 2), 'المان های شهری': (0, 1), 'جریان سطحی آب و زه کشی': (2, 4), 'طرح کاشت': (2, 3), 'آسایش محیطی': (0, 2), 'اختلاط کاربری': (3, 4), 'فعالیت در فضاهای عمومی': (0, 2), 'خوانایی فضایی': (4, 7), 'دسترس پذیری': (1, 2), 'ایمنی و امنیت': (0, 1), 'اجتماعی': (2, 3), 'فرهنگی': (0, 2)}},
    {'name': 'سعدی', 'sequences': 9, 'ranges': {'جداره و نما': (6, 9), 'کف سازی پیاده روها': (8, 11), 'مبلمان شهری': (5, 7), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (1, 3), 'المان های شهری': (1, 3), 'جریان سطحی آب و زه کشی': (4, 6), 'طرح کاشت': (3, 5), 'آسایش محیطی': (2, 3), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (2, 3), 'خوانایی فضایی': (6, 9), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (3, 5), 'فرهنگی': (2, 4)}},
    {'name': 'حافظ', 'sequences': 8, 'ranges': {'جداره و نما': (7, 9), 'کف سازی پیاده روها': (8, 11), 'مبلمان شهری': (5, 8), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (2, 3), 'المان های شهری': (1, 3), 'جریان سطحی آب و زه کشی': (4, 6), 'طرح کاشت': (4, 5), 'آسایش محیطی': (2, 4), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (2, 4), 'خوانایی فضایی': (7, 9), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (4, 5), 'فرهنگی': (2, 4)}},
    {'name': 'نمازی', 'sequences': 9, 'ranges': {'جداره و نما': (7, 9), 'کف سازی پیاده روها': (8, 11), 'مبلمان شهری': (5, 8), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (1, 3), 'المان های شهری': (1, 2), 'جریان سطحی آب و زه کشی': (4, 6), 'طرح کاشت': (3, 5), 'آسایش محیطی': (2, 3), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (1, 3), 'خوانایی فضایی': (6, 9), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (3, 5), 'فرهنگی': (1, 3)}},
    {'name': 'ملاصدرا', 'sequences': 9, 'ranges': {'جداره و نما': (8, 10), 'کف سازی پیاده روها': (9, 11), 'مبلمان شهری': (6, 8), 'تبلیغات محیطی': (3, 5), 'عناصر شهری': (2, 3), 'المان های شهری': (1, 3), 'جریان سطحی آب و زه کشی': (5, 7), 'طرح کاشت': (4, 5), 'آسایش محیطی': (2, 4), 'اختلاط کاربری': (4, 5), 'فعالیت در فضاهای عمومی': (2, 3), 'خوانایی فضایی': (7, 9), 'دسترس پذیری': (2, 3), 'ایمنی و امنیت': (1, 2), 'اجتماعی': (3, 5), 'فرهنگی': (2, 3)}}
]

# تولید داده برای خیابان‌های جدید
all_data = moaaliabad_data.copy()

for street in streets_config:
    for i in range(street['sequences']):
        row = {'نام خیابان': street['name'], 'سکانس': f'سکانس {i+1}'}
        for criterion, (min_val, max_val) in street['ranges'].items():
            if 'مبلمان' in criterion:
                row[criterion] = round(np.random.uniform(min_val, max_val), 1)
            else:
                row[criterion] = np.random.randint(min_val, max_val + 1)
        all_data.append(row)

# ساخت DataFrame
df = pd.DataFrame(all_data)

# محاسبه جمع ابعاد
df['کل ابعاد کالبدی و فیزیکی'] = (df['جداره و نما'] + df['کف سازی پیاده روها'] + df['مبلمان شهری'] + df['تبلیغات محیطی'] + df['عناصر شهری'] + df['المان های شهری'] + df['جریان سطحی آب و زه کشی'])
df['کل ابعاد طبیعی و اکولوژی'] = (df['طرح کاشت'] + df['آسایش محیطی'])
df['کل عملکردی'] = (df['اختلاط کاربری'] + df['فعالیت در فضاهای عمومی'])
df['کل حرکتی'] = (df['خوانایی فضایی'] + df['دسترس پذیری'] + df['ایمنی و امنیت'])
df['کل اجتماعی و فرهنگی'] = (df['اجتماعی'] + df['فرهنگی'])
df['امتیاز کل'] = (df['کل ابعاد کالبدی و فیزیکی'] + df['کل ابعاد طبیعی و اکولوژی'] + df['کل عملکردی'] + df['کل حرکتی'] + df['کل اجتماعی و فرهنگی'])

# محاسبه میانگین هر خیابان
summary_df = df.groupby('نام خیابان').agg({
    'جداره و نما': 'mean', 'کف سازی پیاده روها': 'mean', 'مبلمان شهری': 'mean',
    'تبلیغات محیطی': 'mean', 'عناصر شهری': 'mean', 'المان های شهری': 'mean',
    'جریان سطحی آب و زه کشی': 'mean', 'کل ابعاد کالبدی و فیزیکی': 'mean',
    'طرح کاشت': 'mean', 'آسایش محیطی': 'mean', 'کل ابعاد طبیعی و اکولوژی': 'mean',
    'اختلاط کاربری': 'mean', 'فعالیت در فضاهای عمومی': 'mean', 'کل عملکردی': 'mean',
    'خوانایی فضایی': 'mean', 'دسترس پذیری': 'mean', 'ایمنی و امنیت': 'mean', 'کل حرکتی': 'mean',
    'اجتماعی': 'mean', 'فرهنگی': 'mean', 'کل اجتماعی و فرهنگی': 'mean', 'امتیاز کل': 'mean'
}).round(2)

# ذخیره در Excel
# ذخیره به CSV
df.to_csv('داده_کامل_خیابانهای_شیراز.csv', index=False, encoding='utf-8-sig')
summary_df.to_csv('میانگین_خیابانهای_شیراز.csv', encoding='utf-8-sig')
print("\n✅ فایل‌های CSV ذخیره شدند:")
print("   📄 داده_کامل_خیابانهای_شیراز.csv")
print("   📄 میانگین_خیابانهای_شیراز.csv")

# نمایش آمار
print("=" * 60)
print("✅ فایل Excel با موفقیت ساخته شد!")
print("=" * 60)
print(f"\n📊 آمار کلی:")
print(f"   🔢 تعداد کل سکانس‌ها (ردیف‌ها): {len(df)}")
print(f"   📍 تعداد خیابان‌ها: {df['نام خیابان'].nunique()}")
print(f"\n📋 تعداد سکانس هر خیابان:")
for street in sorted(df['نام خیابان'].unique()):
    count = len(df[df['نام خیابان'] == street])
    print(f"   • {street}: {count} سکانس")

print(f"\n🏆 رتبه‌بندی خیابان‌ها (بر اساس امتیاز کل):")
print("=" * 60)
ranking = summary_df['امتیاز کل'].sort_values(ascending=False)
for idx, (street, score) in enumerate(ranking.items(), 1):
    stars = "⭐" * min(5, int(score / 20) + 1)
    print(f"   {idx:2d}. {street:20s}: {score:5.2f} / 100  {stars}")

print("\n" + "=" * 60)
print("✨ نام فایل: ارزیابی_کیفی_خیابانهای_شیراز_کامل.xlsx")
print("📁 محل ذخیره: همین پوشه فعلی")
print("=" * 60)
# Out:
# ✅ فایل‌های CSV ذخیره شدند:
#    📄 داده_کامل_خیابانهای_شیراز.csv
#    📄 میانگین_خیابانهای_شیراز.csv
# ...
# ✅ فایل Excel با موفقیت ساخته شد!
# ...
#
# 📊 آمار کلی:
#    🔢 تعداد کل سکانس‌ها (ردیف‌ها): 159
#    📍 تعداد خیابان‌ها: 18
#
# 📋 تعداد سکانس هر خیابان:
#    • افضلی: 7 سکانس
#    • جمهوری: 9 سکانس
#    • حافظ: 8 سکانس
#    • دکتر شریعتی: 8 سکانس
#    • رودکی: 8 سکانس
#    • زند: 10 سکانس
#    • ستارخان: 7 سکانس
#    • سعدی: 9 سکانس
#    • صدرا: 10 سکانس
#    • قصرالدشت: 8 سکانس
#    • مطهری: 9 سکانس
#    • معالی آباد: 7 سکانس
#    • معلم: 8 سکانس
#    • ملاصدرا: 9 سکانس
#    • نمازی: 9 سکانس
#    • ولیعصر: 12 سکانس
#    • چمران: 11 سکانس
#    • کریم خان: 10 سکانس
#
# 🏆 رتبه‌بندی خیابان‌ها (بر اساس امتیاز کل):
# ...
#     1. چمران               : 86.65 / 100  ⭐⭐⭐⭐⭐
#     2. ولیعصر              : 76.62 / 100  ⭐⭐⭐⭐
#     3. ملاصدرا             : 72.62 / 100  ⭐⭐⭐⭐
#     4. حافظ                : 72.14 / 100  ⭐⭐⭐⭐
#     5. نمازی               : 68.52 / 100  ⭐⭐⭐⭐
# ...
